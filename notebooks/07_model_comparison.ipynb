# %% [markdown]
# # 07 - Model comparison and error diagnostics
#
# Combines every cached forecast (Part 8). Run `python scripts/run_pipeline.py --stage evaluate` after all model stages (and after adding the Chronos forecast from notebook 06).

# %%
import sys, warnings
from pathlib import Path
sys.path.append(str(Path.cwd().parent / "src"))
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import Image, display

from appliance_energy.config import *
from appliance_energy import data, eda, features, evaluation, plotting

# %%
fc_df = pd.read_csv(FORECAST_DIR / 'all_forecasts.csv',
                    index_col=0, parse_dates=True)
comparison = pd.read_csv(METRICS_DIR / 'model_comparison.csv',
                         index_col=0)
comparison

# %%
display(Image(str(FIGURE_DIR / 'fig07_forecast_comparison.png')))

# %%
display(Image(str(FIGURE_DIR / 'fig10_next24h_ci.png')))

# %%
display(Image(str(FIGURE_DIR / 'fig11_error_diagnostics.png')))

# %% [markdown]
# See the report (Section 9) for the full discussion: which models beat the strongest benchmark, error structure by hour of day, and whether the extra complexity is justified.
